# %% [markdown]
# <a href="https://colab.research.google.com/github/oliviachiang0907/SF-AF-CNN/blob/main/SF_AF_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Colab setup cell — run immediately
# 1) upgrade pip (helps avoid TF wheel mismatches)
# !pip install --upgrade pip --quiet

# 2) optional: show Python version (helps debug TF compatibility)
import sys
print("Python", sys.version)

# 3) Install packages. Use a currently available tensorflow release in Colab.
#    If you specifically need TF 2.12 API compatibility, see notes below.
# !pip install --quiet wfdb neurokit2 heartpy scikit-learn tensorflow==2.19.1 imbalanced-learn

# 4) mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 5) clone repo
# Replace the URL below with your repo's HTTPS URL. If the repo is public, this will work directly.
# If it's private, see authentication options below.
# !git clone https://github.com/oliviachiang0907/SF-AF-CNN.git
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 21.5 MB/s eta 0:00:00
# Python 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# tensorflow-decision-forests 1.12.0 requires tensorflow==2.19.0, but you have tensorflow 2.19.1 which is incompatible.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Cloning into 'SF-AF-CNN'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 11 (delta 3), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (11/11), 4.14 KiB | 605.00 KiB/s, done.
# ...

# %% [markdown]
# #README
# ##insert unimportant objective and timeline/instructions, will do later
